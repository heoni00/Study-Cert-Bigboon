# %% [markdown]
# ## 결측치 제거 및 그룹 합계에서 조건에 맞는 값 찾아 출력
# - 주어진 데이터 중 basic1.csv에서 'f1'컬럼 결측 데이터를 제거하고, 'city'와 'f2'을 기준으로 묶어 합계를 구하고, 'city가 경기이면서 f2가 0'인 조건에 만족하는 f1 값을 구하시오
# - 데이터셋 : basic1.csv
# - 오른쪽 상단 copy&edit 클릭 -> 예상문제 풀이 시작

# %%
# 라이브러리 및 데이터 불러오기

import pandas as pd
import numpy as np 

df = pd.read_csv('/kaggle/input/bigdatacertificationkr/basic1.csv')
df
# Out:
#        id    age city    f1  f2   f3    f4         f5
# 0    id01    2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1    id02    9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2    id03   27.0   서울  61.0   1  NaN  ISTJ  17.252986
# 3    id04   75.0   서울   NaN   2  NaN  INFP  52.667078
# 4    id05   24.0   서울  85.0   2  NaN  ISFJ  29.269869
# ..    ...    ...  ...   ...  ..  ...   ...        ...
# 95   id96   92.0   경기  53.0   1  NaN  ENTJ  52.667078
# 96   id97  100.0   경기   NaN   0  NaN  INFP  67.886373
# 97   id98   39.0   경기  58.0   2  NaN  INFP  98.429899
# 98   id99    1.0   경기  47.0   0  NaN  ESFJ  97.381034
# 99  id100   47.0   경기  53.0   0  vip  ESFP  33.308999
#
# [100 rows x 8 columns]

# %%
# f1컬럼 결측치 제거
df['f1'].dropna() # 해당 시리즈, 리스트의 널값은 삭제 가능하지만! 데이터 프레임을 조정하긴 어려움. 
df = df[~df['f1'].isnull()] # ~ 은 반대!
df.shape
# Out:
# (69, 8)

# %%
# 그룹 합계 계산

temp = df.groupby(['city','f2'], as_index = False).sum()
temp.head()
# Out:
#   city  f2    age     f1          f5
# 0   경기   0  720.4  833.0  943.944823
# 1   경기   1  696.0  670.0  657.241212
# 2   경기   2  239.0  311.0  362.300060
# 3   대구   0  387.0  527.0  183.199568
# 4   대구   1  217.6  235.0  241.333824

# %%
# 조건에 맞는 값 출력

# 'city가 경기이면서 f2가 0'인 조건에 만족하는 f1 값을 구하시오

print(temp[(temp.city == '경기') & (temp.f2 == 0)].f1)
# Out:
# 0    833.0
# Name: f1, dtype: float64

# %% [markdown]
# ## Hint
# - 그룹 합계

# %%
import pandas as pd
df = pd.DataFrame({'User': ['네모', '네모',
                              '세모', '세모'],
                   'Max Speed': [120., 240., 57., 41.]})
df
# Out:
#   User  Max Speed
# 0   네모      120.0
# 1   네모      240.0
# 2   세모       57.0
# 3   세모       41.0

# %%
df.groupby(['User']).mean()
# Out:
#       Max Speed
# User
# 네모        180.0
# 세모         49.0

# %% [markdown]
# ## 풀이

# %%
# 라이브러리 및 데이터 불러오기
import pandas as pd
import numpy as np

df = pd.read_csv('../input/bigdatacertificationkr/basic1.csv')
df.head()
# Out:
#      id   age city    f1  f2   f3    f4         f5
# 0  id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986
# 3  id04  75.0   서울   NaN   2  NaN  INFP  52.667078
# 4  id05  24.0   서울  85.0   2  NaN  ISFJ  29.269869

# %%
# f1컬럼 결측치 제거
df = df[~df['f1'].isnull()]

# %%
# 그룹 합계 계산
df2 = df.groupby(['city','f2']).sum()
df2
# Out:
#            age     f1          f5
# city f2
# 경기   0   720.4  833.0  943.944823
#      1   696.0  670.0  657.241212
#      2   239.0  311.0  362.300060
# 대구   0   387.0  527.0  183.199568
#      1   217.6  235.0  241.333824
#      2   140.0  211.0   79.667919
# 부산   0   331.0  389.0  284.371097
#      1   188.7  315.0  299.270973
#      2   -13.5   47.0   67.886373
# 서울   0   145.0  278.0  218.528577
#      1   315.3  534.0  438.485010
#      2    68.3  207.0  126.661135

# %%
# 조건에 맞는 값 출력
print(df2.iloc[0]['f1'])
# Out:
# 833.0
